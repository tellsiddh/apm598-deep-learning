# %% [markdown]
# APM 598 Homework 2 - 3rd March 2023
#
# Siddharth Jain 1226137070
#
# Ketan Choudhary 1226082301
#
# Pranav Chougule 1225934595

# %% [markdown]
# Q 1A

# %%
import tensorflow.keras as keras
import numpy as np
import gc
print("Q 1A")
#to clear previous TF cached graph
gc.collect()

x = np.array([[1,0], [-1,0], [0,1], [0,-1]]) #X1, X2, X3, X4
y = np.array([[1,0], [1,0], [0,1], [0,1]])   #S1, S1, S2, S2

#model
model = keras.Sequential([
    keras.layers.Dense(2, input_shape=(2,), activation='relu', kernel_initializer='glorot_uniform'),
    keras.layers.Dense(2, activation=None, kernel_initializer='glorot_uniform')
])

#training the model
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=None)
model.fit(x, y, epochs=10000, verbose=0)

#Get Weights and biases of layer 1
weights_1, biases_1 = model.layers[0].get_weights()

#Get Weights and biases of layer 2
weights_2, biases_2 = model.layers[1].get_weights()

print("\nWeights for layer1:\n",weights_1)
print("Biases  for layer1:\n",biases_1,"\n")
print("Weights for layer2:\n",weights_2)
print("Biases  for layer2:\n",biases_2,"\n")

print("Score[s1, s2] for X1 [ 1,0]: ",model.predict(np.array([x[0]])),"\n")
print("Score[s1, s2] for X2 [-1,0]: ",model.predict(np.array([x[1]])),"\n")
print("Score[s1, s2] for X3 [ 0,1]: ",model.predict(np.array([x[2]])),"\n")
print("Score[s1, s2] for X4 [ 0,-1]: ",model.predict(np.array([x[3]])),"\n")

del model
gc.collect()
# Out:
# Q 1A
# training...
#
# Weights for layer1:
#  [[ 1.1349535  -0.2115434 ]
#  [ 0.33902076  0.9033544 ]]
# Biases  for layer1:
#  [-0.31839803 -0.21323949]
#
# Weights for layer2:
#  [[ 0.58303607 -0.67433393]
#  [-0.77666426  0.6701857 ]]
# Biases  for layer2:
#  [0.52405316 0.55094624]
#
# 1/1 [==============================] - 0s 93ms/step
# Score[s1, s2] for X1 [ 1,0]:  [[1.0001345e+00 3.1512976e-04]]
#
# 1/1 [==============================] - 0s 25ms/step
# Score[s1, s2] for X2 [-1,0]:  [[0.52405316 0.55094624]]
#
# 1/1 [==============================] - 0s 24ms/step
# Score[s1, s2] for X3 [ 0,1]:  [[8.9347363e-05 9.9954474e-01]]
#
# 1/1 [==============================] - 0s 23ms/step
# Score[s1, s2] for X4 [ 0,-1]:  [[0.52405316 0.55094624]]
# 4640

# %% [markdown]
# Q 1B

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import gc
print("Q 1B")
# Load and shuffle dataset
df = pd.read_csv('C:\\Users\\siddh\\Documents\\Siddharth\\Classes\\Spring 2023\\APM 598 Introduction to Deep Neural Networks\\HW\\HW 2\\data_HW2_ex1.csv').sample(frac=1).reset_index(drop=True)

# Split into features and classes
x = np.column_stack((df['x1'].values,df['x2'].values))
y = df['class'].values

# Split into training and testing sets
split_ratio = 0.8
split_index = int(split_ratio * len(x))
x_train, x_test = x[:split_index], x[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Define the model architecture
model = Sequential([
    Dense(4, activation='relu', input_shape=(2,)),
    Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.05), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary
# Train the model
history = model.fit(x_train, y_train, epochs=1000, verbose=0)

# Evaluate the model on the test set
score, accuracy = model.evaluate(x_test, y_test)

# Predict classes for the test set
y_pred = np.argmax(model.predict(x_test), axis=1)

# Create a subplot to display the original classes and the predicted classes
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Plot the original classes
ax[0].scatter(x_test[y_test == 1][:, 0], x_test[y_test == 1][:, 1], s=10, c='r', marker="o", label='Class 1')
ax[0].scatter(x_test[y_test == 2][:, 0], x_test[y_test == 2][:, 1], s=10, c='g', marker="^", label='Class 2')
ax[0].set_title("Original Classes")
ax[0].legend(loc='upper left')

# Plot the predicted classes
ax[1].scatter(x_test[y_pred == 1][:, 0], x_test[y_pred == 1][:, 1], s=10, c='r', marker="o", label='Class 1')
ax[1].scatter(x_test[y_pred == 2][:, 0], x_test[y_pred == 2][:, 1], s=10, c='g', marker="^", label='Class 2')
ax[1].set_title("Predicted Classes")
ax[1].legend(loc='upper left')

plt.show()

# Perform garbage collection to free up memory
gc.collect()
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9750
# 2/2 [==============================] - 0s 1ms/step
# 1567

# %% [markdown]
# Q 2A and 2B

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np
print("Q2A and Q2B")
'''Define any function to be used as input'''
def f(x):
    return x**3 - 2*x + 1

def get_data_points(f, start, end, num_points):
    '''Generate data points'''
    x = torch.linspace(start, end, num_points).reshape(-1, 1)
    y = f(x)
    return x, y

def get_plotting_points(f, start, end, num_points):
    '''Generate points for plotting the function'''
    x = torch.linspace(start, end, num_points).reshape(-1, 1)
    y = f(x)
    return x, y

class Net(nn.Module):
    def __init__(self, n_feature, n_hidden, n_output):
        super(Net, self).__init__()
        self.hidden = nn.Linear(n_feature, n_hidden)
        self.predict = nn.Linear(n_hidden, n_output)
  
    def forward(self, x):
        x = nn.functional.relu(self.hidden(x)) # ReLU activation
        x = self.predict(x)
        return x

def train_model(model, optimizer, criterion, dataloader, num_epochs):
    '''Train the neural network model'''
    losses = []
    for epoch in range(num_epochs):
        epoch_loss = 0
        for x, y in dataloader:
            optimizer.zero_grad()
            y_pred = model(x)
            loss = criterion(y_pred, y)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        losses.append(epoch_loss)
    return model, losses

def piecewise_linear(f, start, end, num_points):
    '''Fit a piecewise linear function to the input function'''
    x, y = get_data_points(f, start, end, num_points+1)
    dataset = TensorDataset(x, y)
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
    model = Net(n_feature=1, n_hidden=num_points+1, n_output=1)
    #print(model)
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    criterion = nn.MSELoss()
    trained_model, losses = train_model(model, optimizer, criterion, dataloader, num_epochs=500)
    p_x, p_y = get_plotting_points(f, start, end, 500)
    y_pred = trained_model(p_x)
    #print("\nThe predicted values for the given X: ", y_pred.data.numpy())
    plt.figure(figsize=(10,4))
    plt.plot(p_x.data.numpy(), p_y.data.numpy(), color="black", label='Function')
    plt.scatter(x.data.numpy(), y.data.numpy(), color="red")
    plt.scatter(p_x.data.numpy(), y_pred.data.numpy(), color="orange")
    plt.plot(p_x.data.numpy(), y_pred.data.numpy(), color="orange", label='Piecewise Linear Fit')
    plt.title('Piecewise Linear Fit to Function')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.show()
    print("Trained Network:\nNumber of nodes in hidden layer: {} (num_points+1)".format(num_points+1))
    for name, param in trained_model.named_parameters(): 
        if param.requires_grad: 
            print(name, param.data)
    return trained_model, losses

def main():
    print()
    print("Number of points is 3")
    piecewise_linear(f, start=-2, end=2, num_points=3)
    print()
    print("Number of points is 10")
    piecewise_linear(f, start=-2, end=2, num_points=10)
    print()
    print("Number of points is 25")
    piecewise_linear(f, start=-2, end=2, num_points=25)

if __name__ == '__main__':
    main()
# Out:
# Q2A and Q2B
#
# Number of points is 3
# Trained Network:
# Number of nodes in hidden layer: 4 (num_points+1)
# hidden.weight tensor([[-0.7296],
#         [-0.4928],
#         [ 0.5730],
#         [ 1.4541]])
# hidden.bias tensor([ 2.2860, -0.9859,  1.4960, -0.9709])
# predict.weight tensor([[-0.7274,  0.4172,  1.0129,  1.2235]])
# predict.bias tensor([0.5552])
#
# Number of points is 10
# Trained Network:
# Number of nodes in hidden layer: 11 (num_points+1)
# hidden.weight tensor([[-2.9252e-01],
#         [ 1.4850e+00],
#         [ 2.5294e+00],
#         [-2.4116e+00],
#         [-3.2056e-01],
#         [-6.7032e-02],
#         [ 1.0758e+00],
#         [-1.7669e-01],
#         [-2.1668e-03],
#         [-1.0428e+00],
#         [-5.0253e-01]])
# hidden.bias tensor([-0.8242, -1.4057, -2.8359, -2.6792, -0.8386,  1.3245,  0.5137, -0.6384,
#          0.8700,  1.1278,  0.5541])
# predict.weight tensor([[-0.2468,  0.9945,  1.9004, -2.8725,  0.1702,  0.1193, -0.4080, -0.0659,
#          -0.1635,  0.8689,  0.3476]])
# predict.bias tensor([0.0497])
#
# Number of points is 25
# Trained Network:
# Number of nodes in hidden layer: 26 (num_points+1)
# hidden.weight tensor([[ 0.1231],
#         [-1.3295],
#         [-0.3945],
#         [ 0.1702],
#         [-0.0128],
#         [-0.5845],
#         [ 0.1512],
#         [ 0.4325],
#         [-1.3151],
#         [-1.4069],
#         [-0.7412],
#         [ 2.0664],
#         [-1.3666],
#         [-1.1234],
#         [-1.3033],
#         [-0.1646],
#         [ 0.5669],
#         [ 0.3191],
#         [ 0.4806],
#         [ 0.4675],
#         [ 0.3582],
#         [-1.5539],
#         [-1.3051],
#         [ 1.5045],
#         [-2.0918],
#         [-0.4430]])
# hidden.bias tensor([ 0.2466, -2.0664, -0.8820,  0.3408,  0.9250,  1.1730,  0.3026, -1.0735,
#         -1.2935, -0.7046,  1.4904, -3.0273, -0.6212, -1.8874,  1.0394, -0.5029,
#          1.1341,  0.6383,  0.8087,  0.9352,  0.7165, -1.5368, -1.7902, -0.7267,
#          2.1519,  0.8933])
# predict.weight tensor([[ 0.1552, -1.3944, -0.0565,  0.1437, -0.0930, -0.4087,  0.0743,  0.0217,
#          -1.1284, -0.4970, -0.7811,  2.2568, -0.4514, -1.4664,  0.7799,  0.0298,
#           0.1510,  0.1603, -0.2381,  0.1052,  0.1210, -1.0932, -1.2495,  0.8080,
#           0.9719, -0.4346]])
# predict.bias tensor([-0.1611])

# %% [markdown]
# Piecewise Interpolation

# %%
gx = lambda x: np.sin(np.pi * x)
piecewise_linear(gx, start=-2, end=2, num_points=200)

gx = lambda x: np.cosh(np.pi * x)
piecewise_linear(gx, start=-2, end=2, num_points=200)
# Out:
# Trained Network:
# Number of nodes in hidden layer: 201 (num_points+1)
# hidden.weight tensor([[ 1.1428e+00],
#         [-4.0097e-01],
#         [ 6.7460e-01],
#         [-1.1757e+00],
#         [ 8.2221e-01],
#         [ 2.3316e-01],
#         [ 4.9950e-01],
#         [ 7.7658e-01],
#         [ 1.2396e-02],
#         [ 2.5632e-01],
#         [ 3.9102e-02],
#         [-5.2259e-01],
#         [ 2.1545e-01],
#         [ 5.1589e-01],
#         [-4.3426e-01],
#         [-4.2778e-01],
#         [ 3.5306e-01],
#         [ 2.2099e-01],
#         [-7.7168e-01],
#         [-4.9583e-01],
#         [ 1.0412e-01],
#         [ 7.2305e-01],
#         [ 7.5443e-01],
#         [-1.8237e-01],
#         [ 6.3562e-01],
#         [ 8.3488e-01],
#         [ 7.8570e-01],
#         [ 5.2400e-01],
#         [-2.2192e-01],
#         [-3.6841e-01],
#         [-6.1150e-01],
#         [-7.6322e-01],
#         [ 9.6353e-01],
#         [ 3.3976e-01],
#         [ 7.6125e-02],
#         [-3.5581e-01],
#         [-1.0646e+00],
#         [ 8.2080e-01],
#         [ 7.4222e-02],
#         [ 1.6860e-01],
#         [-3.7939e-01],
#         [-1.8762e-01],
#         [-5.1402e-02],
#         [-1.8199e-01],
#         [ 6.7047e-01],
#         [-4.0811e-02],
#         [-6.7726e-01],
#         [-1.0353e+00],
#         [ 6.0465e-03],
#         [ 7.7263e-01],
#         [-4.7207e-01],
#         [ 4.7230e-01],
#         [-2.2276e-01],
#         [-2.9446e-03],
#         [ 6.2826e-01],
#         [-2.0091e-01],
#         [ 3.0190e-01],
#         [-6.3680e-01],
#         [ 4.9396e-02],
#         [-5.6465e-02],
#         [-9.3641e-01],
#         [-1.1051e-01],
#         [ 9.0438e-01],
#         [-1.0196e-01],
#         [ 6.5596e-01],
#         [ 8.3284e-01],
#         [-4.5256e-01],
#         [ 4.3657e-01],
#         [ 1.5623e-03],
#         [-2.0004e-01],
#         [ 6.9031e-01],
#         [ 2.4658e-02],
#         [ 2.1600e-01],
#         [-4.5282e-01],
#         [ 5.1173e-01],
#         [-4.8091e-01],
#         [-6.7666e-01],
#         [-1.7990e-01],
#         [-1.0049e+00],
#         [ 8.2359e-01],
#         [-1.9232e-01],
#         [-1.1909e-01],
#         [-1.1777e-01],
#         [-2.8323e-01],
#         [-7.7666e-01],
#         [ 2.8742e-01],
#         [ 1.0881e+00],
#         [-1.1462e+00],
#         [ 3.9003e-01],
#         [-4.2814e-02],
#         [-8.4198e-01],
#         [-6.7707e-01],
#         [ 3.0062e-01],
#         [-7.8843e-01],
#         [-3.2250e-01],
#         [-8.4527e-02],
#         [ 1.4274e-02],
#         [-1.2578e+00],
#         [ 7.6225e-01],
#         [ 4.4621e-01],
#         [-2.9437e-01],
#         [ 6.3414e-01],
#         [ 3.9945e-01],
#         [-1.0031e+00],
#         [-8.5494e-07],
#         [ 8.0699e-01],
#         [ 6.3712e-01],
#         [ 8.6027e-01],
#         [-2.0818e-01],
#         [ 8.6861e-01],
#         [-2.3745e-01],
#         [-3.7715e-01],
#         [ 3.7565e-01],
#         [ 4.1063e-01],
#         [-1.0356e-01],
#         [ 1.5555e-02],
#         [ 1.2193e-01],
#         [ 8.9637e-01],
#         [-3.3029e-01],
#         [ 9.9377e-01],
#         [-6.0214e-01],
#         [-6.1211e-01],
#         [-9.0091e-02],
#         [ 3.6266e-01],
#         [ 2.4291e-02],
#         [-2.1113e-01],
#         [ 1.2876e-02],
#         [ 6.8733e-01],
#         [-7.3573e-01],
#         [ 8.0978e-01],
#         [-8.4776e-01],
#         [ 5.1269e-01],
#         [ 9.3435e-01],
#         [-7.6067e-01],
#         [-5.8556e-01],
#         [ 4.9405e-01],
#         [-9.3594e-01],
#         [ 5.8041e-01],
#         [ 6.1043e-01],
#         [ 1.1148e-01],
#         [-7.0203e-01],
#         [-4.3720e-01],
#         [-3.9807e-01],
#         [ 4.3780e-01],
#         [ 8.1264e-04],
#         [ 9.6366e-01],
#         [ 7.9211e-04],
#         [ 6.8935e-01],
#         [ 1.8652e-05],
#         [-6.1394e-01],
#         [-7.8667e-01],
#         [ 8.7644e-02],
#         [ 7.7324e-01],
#         [-2.0008e-01],
#         [-8.3842e-01],
#         [ 7.7794e-01],
#         [-6.2806e-01],
#         [-7.0751e-01],
#         [-4.4605e-01],
#         [-2.5529e-01],
#         [ 1.3896e-01],
#         [-4.2235e-02],
#         [-1.9177e-01],
#         [ 5.6033e-02],
#         [ 2.7336e-01],
#         [-3.6672e-01],
#         [-4.0707e-01],
#         [-1.0221e-02],
#         [ 5.1991e-01],
#         [ 8.3618e-01],
#         [ 7.0531e-01],
#         [-4.4052e-02],
#         [-3.1491e-01],
#         [ 8.1840e-03],
#         [ 1.1361e+00],
#         [ 1.4472e-03],
#         [-5.2538e-01],
#         [-1.0593e+00],
#         [ 9.2209e-01],
#         [ 9.7429e-01],
#         [ 2.6266e-01],
#         [-9.7014e-01],
#         [ 9.1810e-01],
#         [-5.4437e-01],
#         [-1.1049e+00],
#         [ 4.8534e-01],
#         [ 3.7063e-01],
#         [-1.3812e-01],
#         [ 3.9486e-01],
#         [-1.7504e-01],
#         [ 2.6157e-02],
#         [ 1.0403e-02],
#         [-7.8663e-01],
#         [-1.0116e+00],
#         [ 7.6121e-01],
#         [ 4.4077e-01],
#         [ 5.3982e-01],
#         [ 4.3924e-01],
#         [-2.0973e-01],
#         [-5.2809e-01],
#         [ 8.0819e-01]])
# hidden.bias tensor([-8.2030e-01, -8.9605e-01,  4.3682e-01, -6.6762e-01,  1.7351e-01,
#          5.6907e-01,  5.9031e-01,  1.9012e-01,  3.4798e-02,  6.3320e-01,
#          1.5250e-01, -3.9184e-01, -8.2752e-01, -4.3776e-01,  6.4386e-02,
#          6.3188e-02, -2.9778e-01,  2.6068e-01, -3.2677e-01, -4.1748e-01,
#         -5.7515e-01,  4.5646e-01,  9.0703e-01,  2.8824e-01,  1.0582e-01,
#          -8.6593e-02, -5.6613e-02, -2.7060e-01,  2.0958e-02, -1.5935e-01,
#          -3.1985e-01, -9.1810e-02,  9.0315e-02, -1.3853e-01, -6.4920e-03,
#           1.4635e-02, -4.4417e-03, -4.0407e-02, -1.7282e-03,  5.1148e-02,
#           5.4351e-03, -2.3672e-02,  2.8737e-02,  1.8557e-01,  1.8615e-01,
#           1.2621e-01,  4.8470e-03,  3.5655e-02,  1.0349e-02,  1.2326e-01,
#          -5.1941e-03, -1.3111e-01,  3.2170e-01, -2.5745e-01,  1.7181e-01,
#           1.4770e-01, -1.0386e-01,  1.2461e+00,  5.6442e-02, -1.3732e-01,
#          -1.4433e-01, -8.3810e-02,  4.5593e-02,  5.7387e-02,  5.9003e-02,
#           1.2781e-03, -1.3120e-03, -6.5275e-02,  2.8374e-01,  7.0375e-02,
#          -2.9655e-03,  1.6092e-01, -1.9024e-02,  2.7824e-02,  9.1401e-02,
#           1.6738e-01]])
# predict.bias tensor([0.0961])
# Trained Network:
# Number of nodes in hidden layer: 201 (num_points+1)
# hidden.weight tensor([[ 2.2640],
#         [ 2.2682],
#         [-2.2102],
#         [ 2.1456],
#         [ 2.2325],
#         [ 2.1960],
#         [ 1.9217],
#         [ 1.8311],
#         [-0.2790],
#         [-2.1236],
#         [ 1.7509],
#         [-2.5615],
#         [-2.5464],
#         [-2.3858],
#         [-2.1987],
#         [-1.9360],
#         [-0.2531],
#         [-0.2341],
#         [ 2.0732],
#         [-2.5390],
#         [-2.1655],
#         [-2.4247],
#         [ 0.2884],
#         [-2.0343],
#         [ 2.1491],
#         [ 0.0513],
#         [ 2.0059],
#         [-2.3880],
#         [-2.2995],
#         [-2.2110],
#         [-2.0001],
#         [ 0.1494],
#         [-1.7846],
#         [ 2.3365],
#         [-2.5566],
#         [ 1.9818],
#         [ 2.3006],
#         [ 2.4181],
#         [-2.1219],
#         [ 2.4394],
#         [ 2.5569],
#         [ 0.6407],
#         [ 1.0179],
#         [-2.4287],
#         [-1.8511],
#         [ 2.4057],
#         [ 2.0283],
#         [-0.1727],
#         [ 1.9221],
#         [ 2.2159],
#         [ 2.2008],
#         [ 1.9727],
#         [ 2.3105],
#         [-1.8555],
#         [ 2.4032],
#         [ 2.2665],
#         [ 2.1856],
#         [-2.1920],
#         [ 2.3237],
#         [-2.5432],
#         [ 2.3878],
#         [-2.2717],
#         [ 2.0675],
#         [-2.0982],
#         [-1.9113],
#         [ 0.2376],
#         [-0.3447],
#         [ 1.9606],
#         [-1.9459],
#         [-2.2281],
#         [-2.4145],
#         [-0.2883],
#         [-0.1387],
#         [-0.2884],
#         [ 2.0532],
#         [ 0.0885],
#         [ 0.3771],
#         [-2.0020],
#         [-2.0602],
#         [ 0.0793],
#         [-2.1068],
#         [ 2.4802],
#         [ 0.1176],
#         [ 2.1540],
#         [ 2.0318],
#         [ 2.2921],
#         [-2.0526],
#         [ 0.3453],
#         [ 0.3201],
#         [ 2.1079],
#         [ 1.9512],
#         [-0.0066],
#         [ 0.2160],
#         [ 2.5418],
#         [ 0.2912],
#         [-0.3443],
#         [ 2.1733],
#         [-2.0516],
#         [ 2.3936],
#         [ 0.2081],
#         [ 0.1150],
#         [-2.3808],
#         [ 2.5973],
#         [-0.1984],
#         [ 2.0452],
#         [ 0.3082],
#         [ 2.4439],
#         [-2.1169],
#         [-0.0302],
#         [-0.0125],
#         [-2.0368],
#         [-0.1207],
#         [ 0.1743],
#         [ 0.0566],
#         [ 2.5165],
#         [-2.2386],
#         [-2.1970],
#         [ 2.0702],
#         [ 2.1704],
#         [-2.1316],
#         [-2.1495],
#         [-2.5376],
#         [ 2.3376],
#         [-2.0670],
#         [-0.0080],
#         [ 0.4354],
#         [-2.2845],
#         [ 2.1486],
#         [-2.0764],
#         [-2.3129],
#         [-2.3603],
#         [ 2.0152],
#         [ 2.2753],
#         [ 1.9320],
#         [-0.0070],
#         [-2.1379],
#         [ 1.9975],
#         [ 1.8831],
#         [-2.5679],
#         [-2.2107],
#         [-0.1034],
#         [ 1.9940],
#         [-2.4233],
#         [ 2.1507],
#         [ 0.2560],
#         [-2.4288],
#         [-2.2566],
#         [-1.9456],
#         [ 0.0523],
#         [-2.2091],
#         [ 0.0539],
#         [ 1.8903],
#         [-2.5515],
#         [-2.4661],
#         [-2.1495],
#         [-2.2339],
#         [-0.1094],
#         [-2.2681],
#         [-2.3914],
#         [-2.2423],
#         [ 2.1219],
#         [-2.1746],
#         [ 2.2597],
#         [ 0.7660],
#         [ 1.8812],
#         [ 0.3812],
#         [-2.5992],
#         [-2.1340],
#         [ 2.0847],
#         [ 2.2543],
#         [-2.2719],
#         [-2.4967],
#         [ 2.4937],
#         [-2.1943],
#         [-2.0031],
#         [-2.1413],
#         [ 2.0644],
#         [-2.1701],
#         [ 1.9584],
#         [ 2.0553],
#         [ 1.8908],
#         [-1.7654],
#         [ 2.3636],
#         [-1.9666],
#         [ 2.2118],
#         [-0.0523],
#         [ 2.5036],
#         [-2.5745],
#         [ 1.9147],
#         [-2.4951],
#         [-2.3060],
#         [ 1.9879],
#         [-1.9672],
#         [ 2.3076],
#         [-1.8208],
#         [ 2.3467],
#         [ 2.0130],
#         [-1.9162],
#         [-0.3098],
#         [-2.1460],
#         [ 2.1318]])
# hidden.bias tensor([-1.6514, -3.6998, -3.8108, -3.5729, -3.6446, -1.9178, -3.3719, -3.2201,
#         -0.8558, -3.6857, -3.0838, -3.5035, -3.9685, -3.9471, -3.7603, -3.3816,
#         -0.6798, -0.6969, -3.5033, -3.6471, -3.7504, -3.8444,  1.2132, -3.5485,
#         -2.7237, -0.7502, -1.8458,  0.0667, -3.6490, -3.3022, -3.4926,  1.2090,
#         -3.1260, -3.6501, -3.1352, -3.4754, -3.1860, -3.6708, -0.6259, -2.6362,
#         -3.8018,  0.9731,  1.5617, -3.6609, -3.2391, -3.0782, -3.5332,  1.2723,
#         -3.3706, -3.1488, -2.6775, -3.4576, -2.4270, -3.2426, -3.7303,  1.1301,
#          1.1269, -1.5801, -2.8712, -3.6473, -3.8139, -3.7937, -3.5429, -3.6593,
#         -3.3401,  1.1657, -0.9617, -3.4402, -2.9341, -2.1221, -2.3700, -0.7393,
#         -0.5752, -0.7601, -3.5693, -0.2922, -0.8273, -3.4923, -3.5927,  0.9161,
#           4.0334e+00,  1.2346e+00, -2.9294e-01,  3.9174e+00,  1.8053e+00,
#           1.3134e+00,  1.3450e+00, -2.6648e-01,  5.0097e-02,  1.9448e+00,
#           4.5382e+00,  3.2134e-03, -4.1632e-02,  3.6639e+00, -6.6884e-02,
#          -3.5659e-01,  2.7312e+00,  2.4763e+00,  1.1643e+00, -4.8907e-02,
#          -3.6374e-01,  4.5305e+00,  4.0659e+00,  4.8340e-02,  4.9035e+00,
#          -1.3651e-01,  2.1207e+00,  9.2957e-01, -4.1520e-01, -3.1833e-01,
#           1.6171e+00,  4.8791e-02, -3.7810e-01,  3.5699e-02,  2.3750e+00,
#           1.5955e+00,  1.3418e+00,  1.0988e+00,  1.3809e+00,  1.8859e+00,
#           4.9641e+00,  8.9451e-01,  2.5335e+00,  5.0913e+00,  6.5552e-02,
#           2.5265e-02,  2.4523e+00,  2.4524e+00,  4.2140e+00,  2.4087e+00,
#           2.1557e+00,  2.4243e+00,  1.8864e+00,  5.2478e+00,  2.7481e-03,
#           2.2268e+00,  1.0340e+00,  3.1513e+00,  4.2152e+00,  1.1437e+00,
#          -3.3993e-02,  4.7900e+00,  2.2481e+00,  3.4239e+00, -1.8984e-02,
#           3.7141e+00,  3.9771e+00,  2.7272e+00,  4.5147e-02,  1.8989e+00,
#          -3.0510e-02,  1.4626e+00,  4.0722e+00,  1.5207e+00,  3.4101e+00,
#           3.9358e+00, -2.9697e-01,  4.9848e+00,  1.6994e+00,  3.3835e+00,
#           3.2855e+00,  3.4451e+00,  4.8250e+00,  9.2693e-01,  4.5754e+00,
#          -3.3235e-01,  3.8420e+00,  9.9374e-01,  2.5505e+00,  2.6322e+00,
#           2.1605e+00,  2.3416e+00,  3.9977e+00,  2.3883e+00,  8.7738e-01,
#           9.7596e-01,  4.6365e+00,  4.2845e+00,  2.0506e+00,  3.2478e+00,
#           2.8341e+00,  8.9511e-01,  2.6753e+00,  4.1101e+00,  4.7667e+00,
#          -2.3793e-01,  2.2149e+00,  2.0714e+00,  3.2315e+00,  3.0150e+00,
#           2.6280e+00,  5.3950e+00,  3.2232e+00,  1.2384e+00,  2.1247e+00,
#           3.4059e+00,  3.7128e+00,  3.0256e+00, -3.6668e-01,  2.3544e+00,
#           4.9137e+00]])
# predict.bias tensor([-0.4721])
# (Net(
#    (hidden): Linear(in_features=1, out_features=201, bias=True)
#    (predict): Linear(in_features=201, out_features=1, bias=True)
#  ),
#  [38540.92724609375,
#   39167.48327636719,
#   34558.375,
#   27355.077270507812,
#   24621.923583984375,
#   21481.571655273438,
#   20271.326904296875,
#   18084.59912109375,
#   17451.994750976562,
#   16675.09912109375,
#   15489.106323242188,
#   14563.004211425781,
#   14100.592895507812,
#   15008.484619140625,
#   12936.868225097656,
#   13147.6279296875,
#   14530.686157226562,
#   12065.708312988281,
#   11630.297302246094,
#   14595.795593261719,
#   11040.173034667969,
#   10872.522338867188,
#   11053.007080078125,
#   11404.056396484375,
#   10376.840759277344,
#   10724.175109863281,
#   10974.770629882812,
#   9006.164123535156,
#   10476.71923828125,
#   9159.3544921875,
#   10181.3466796875,
#   8612.829223632812,
#   108.98427474498749,
#   73.78862619400024,
#   62.619184255599976,
#   63.098647594451904,
#   100.18910276889801,
#   84.80745935440063,
#   69.64771318435669,
#   59.014785408973694,
#   96.0047402381897,
#   100.45902466773987,
#   71.41562885046005,
#   64.87493073940277,
#   70.47738313674927,
#   62.01844525337219,
#   62.405444860458374,
#   56.44026482105255,
#   55.16595819592476,
#   54.35893052816391,
#   56.58323871344328,
#   56.64790388941765,
#   53.54219138622284,
#   52.84939044713974,
#   60.75202965736389,
#   47.922773629426956,
#   51.02022209763527,
#   48.77679068595171,
#   63.398184180259705,
#   61.64295622706413,
#   52.532081961631775,
#   60.911451518535614,
#   52.41591429710388,
#   57.99768304824829,
#   47.113478258252144,
#   50.75513172149658,
#   57.521285355091095,
#   48.16569846868515,
#   88.63700127601624,
#   69.14533615112305,
#   68.24127918481827,
#   52.07340621948242,
#   64.90801954269409,
#   52.963394463062286,
#   46.94602574408054,
#   49.93008017539978,
#   114.5305404663086])

# %% [markdown]
# Q3

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout
from tensorflow.keras import regularizers

# Load Fashion-MNIST data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape data to be suitable for convolutional layers
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Define model architecture with L2 regularization
'''
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
'''

model = Sequential()
model.add(Conv2D(4, (2, 2), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(2, (2, 2), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
#model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
#model.add(Conv2D(10, (2, 2), activation='softmax'))
model.add(Dense(10, activation='softmax'))

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))

# Evaluate model on test set
test_loss, test_acc = model.evaluate(x_test, y_test)
train_loss, train_acc = model.evaluate(x_train, y_train)

print('    loss     (train, test): {:.4f},  {:.4f}'.format(train_loss, test_loss))
print('    accuracy (train, test): {:.4f},  {:.4f}'.format(train_acc, test_acc)) 

import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

#print('Training accuracy:', history.history['accuracy'][-1])
print('Train accuracy:', train_acc)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6882 - accuracy: 0.7565 - val_loss: 0.5080 - val_accuracy: 0.8191
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5196 - accuracy: 0.8166 - val_loss: 0.4747 - val_accuracy: 0.8344
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4992 - accuracy: 0.8254 - val_loss: 0.4588 - val_accuracy: 0.8374
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4849 - accuracy: 0.8271 - val_loss: 0.4595 - val_accuracy: 0.8420
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4755 - accuracy: 0.8324 - val_loss: 0.4428 - val_accuracy: 0.8481
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4684 - accuracy: 0.8336 - val_loss: 0.4457 - val_accuracy: 0.8460
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4672 - accuracy: 0.8343 - val_loss: 0.4420 - val_accuracy: 0.8460
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4657 - accuracy: 0.8347 - val_loss: 0.4412 - val_accuracy: 0.8464
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4605 - accuracy: 0.8387 - val_loss: 0.4396 - val_accuracy: 0.8480
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4610 - accuracy: 0.8377 - val_loss: 0.4325 - val_accuracy: 0.8500
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4555 - accuracy: 0.8395 - val_loss: 0.4436 - val_accuracy: 0.8427
# Epoch 12/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4545 - accuracy: 0.8379 - val_loss: 0.4294 - val_accuracy: 0.8491
# Epoch 13/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4540 - accuracy: 0.8390 - val_loss: 0.4239 - val_accuracy: 0.8548
# Epoch 14/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4484 - accuracy: 0.8414 - val_loss: 0.4306 - val_accuracy: 0.8454
# Epoch 15/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4484 - accuracy: 0.8421 - val_loss: 0.4283 - val_accuracy: 0.8494
# Epoch 16/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4472 - accuracy: 0.8411 - val_loss: 0.4259 - val_accuracy: 0.8494
# Epoch 17/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4454 - accuracy: 0.8432 - val_loss: 0.4290 - val_accuracy: 0.8458
# Epoch 18/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4424 - accuracy: 0.8435 - val_loss: 0.4196 - val_accuracy: 0.8517
# Epoch 19/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4425 - accuracy: 0.8439 - val_loss: 0.4255 - val_accuracy: 0.8477
# Epoch 20/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4403 - accuracy: 0.8451 - val_loss: 0.4199 - val_accuracy: 0.8539
# Epoch 21/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4387 - accuracy: 0.8445 - val_loss: 0.4152 - val_accuracy: 0.8565
# Epoch 22/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4390 - accuracy: 0.8456 - val_loss: 0.4154 - val_accuracy: 0.8551
# Epoch 23/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4362 - accuracy: 0.8451 - val_loss: 0.4135 - val_accuracy: 0.8571
# Epoch 24/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4363 - accuracy: 0.8458 - val_loss: 0.4160 - val_accuracy: 0.8554
# Epoch 25/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4354 - accuracy: 0.8471 - val_loss: 0.4104 - val_accuracy: 0.8586
# Epoch 26/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4361 - accuracy: 0.8463 - val_loss: 0.4106 - val_accuracy: 0.8561
# Epoch 27/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4342 - accuracy: 0.8460 - val_loss: 0.4101 - val_accuracy: 0.8548
# Epoch 28/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4335 - accuracy: 0.8467 - val_loss: 0.4146 - val_accuracy: 0.8571
# Epoch 29/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4310 - accuracy: 0.8486 - val_loss: 0.4079 - val_accuracy: 0.8612
# Epoch 30/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4302 - accuracy: 0.8484 - val_loss: 0.4168 - val_accuracy: 0.8565
# Epoch 31/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4308 - accuracy: 0.8468 - val_loss: 0.4063 - val_accuracy: 0.8589
# Epoch 32/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4300 - accuracy: 0.8491 - val_loss: 0.4068 - val_accuracy: 0.8602
# Epoch 33/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4288 - accuracy: 0.8485 - val_loss: 0.4076 - val_accuracy: 0.8579
# Epoch 34/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4290 - accuracy: 0.8490 - val_loss: 0.4085 - val_accuracy: 0.8597
# Epoch 35/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4245 - accuracy: 0.8505 - val_loss: 0.4055 - val_accuracy: 0.8559
# Epoch 36/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4259 - accuracy: 0.8505 - val_loss: 0.4066 - val_accuracy: 0.8577
# Epoch 37/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4267 - accuracy: 0.8497 - val_loss: 0.4061 - val_accuracy: 0.8571
# Epoch 38/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4274 - accuracy: 0.8490 - val_loss: 0.4076 - val_accuracy: 0.8588
# Epoch 39/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4245 - accuracy: 0.8503 - val_loss: 0.4015 - val_accuracy: 0.8592
# Epoch 40/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4265 - accuracy: 0.8499 - val_loss: 0.4014 - val_accuracy: 0.8593
# Epoch 41/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4244 - accuracy: 0.8496 - val_loss: 0.4102 - val_accuracy: 0.8538
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4241 - accuracy: 0.8498 - val_loss: 0.4108 - val_accuracy: 0.8567
# Epoch 43/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4234 - accuracy: 0.8483 - val_loss: 0.4056 - val_accuracy: 0.8583
# Epoch 44/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4235 - accuracy: 0.8528 - val_loss: 0.4056 - val_accuracy: 0.8617
# Epoch 45/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4219 - accuracy: 0.8506 - val_loss: 0.4023 - val_accuracy: 0.8606
# Epoch 46/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4227 - accuracy: 0.8499 - val_loss: 0.4034 - val_accuracy: 0.8598
# Epoch 47/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4233 - accuracy: 0.8501 - val_loss: 0.4051 - val_accuracy: 0.8610
# Epoch 48/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4216 - accuracy: 0.8507 - val_loss: 0.4032 - val_accuracy: 0.8583
# Epoch 49/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4224 - accuracy: 0.8507 - val_loss: 0.4076 - val_accuracy: 0.8602
# Epoch 50/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4207 - accuracy: 0.8510 - val_loss: 0.4024 - val_accuracy: 0.8593
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4216 - accuracy: 0.8514 - val_loss: 0.4012 - val_accuracy: 0.8598
# Epoch 52/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4210 - accuracy: 0.8522 - val_loss: 0.3984 - val_accuracy: 0.8591
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4207 - accuracy: 0.8525 - val_loss: 0.4030 - val_accuracy: 0.8597
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4215 - accuracy: 0.8516 - val_loss: 0.4025 - val_accuracy: 0.8612
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4195 - accuracy: 0.8508 - val_loss: 0.4000 - val_accuracy: 0.8603
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4192 - accuracy: 0.8522 - val_loss: 0.4015 - val_accuracy: 0.8611
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4183 - accuracy: 0.8524 - val_loss: 0.3981 - val_accuracy: 0.8615
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4200 - accuracy: 0.8521 - val_loss: 0.3992 - val_accuracy: 0.8590
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4175 - accuracy: 0.8516 - val_loss: 0.4035 - val_accuracy: 0.8591
# Epoch 60/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4199 - accuracy: 0.8524 - val_loss: 0.3950 - val_accuracy: 0.8644
# Epoch 61/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4169 - accuracy: 0.8527 - val_loss: 0.3971 - val_accuracy: 0.8608
# Epoch 62/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4172 - accuracy: 0.8523 - val_loss: 0.3934 - val_accuracy: 0.8627
# Epoch 63/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4161 - accuracy: 0.8519 - val_loss: 0.3997 - val_accuracy: 0.8605
# Epoch 64/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4159 - accuracy: 0.8536 - val_loss: 0.3973 - val_accuracy: 0.8629
# Epoch 65/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4139 - accuracy: 0.8533 - val_loss: 0.4006 - val_accuracy: 0.8592
# Epoch 66/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4154 - accuracy: 0.8542 - val_loss: 0.3979 - val_accuracy: 0.8620
# Epoch 67/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4141 - accuracy: 0.8550 - val_loss: 0.3957 - val_accuracy: 0.8629
# Epoch 68/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4145 - accuracy: 0.8533 - val_loss: 0.3928 - val_accuracy: 0.8621
# Epoch 69/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4153 - accuracy: 0.8536 - val_loss: 0.3949 - val_accuracy: 0.8638
# Epoch 70/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4131 - accuracy: 0.8543 - val_loss: 0.4015 - val_accuracy: 0.8605
# Epoch 71/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4137 - accuracy: 0.8532 - val_loss: 0.3919 - val_accuracy: 0.8628
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4122 - accuracy: 0.8546 - val_loss: 0.3952 - val_accuracy: 0.8640
# Epoch 73/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4139 - accuracy: 0.8542 - val_loss: 0.3928 - val_accuracy: 0.8631
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4149 - accuracy: 0.8530 - val_loss: 0.3905 - val_accuracy: 0.8637
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4140 - accuracy: 0.8535 - val_loss: 0.3900 - val_accuracy: 0.8654
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4146 - accuracy: 0.8539 - val_loss: 0.3984 - val_accuracy: 0.8611
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4134 - accuracy: 0.8538 - val_loss: 0.3913 - val_accuracy: 0.8627
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4109 - accuracy: 0.8551 - val_loss: 0.3879 - val_accuracy: 0.8630
# Epoch 79/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4108 - accuracy: 0.8537 - val_loss: 0.3952 - val_accuracy: 0.8641
# Epoch 80/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4101 - accuracy: 0.8542 - val_loss: 0.3890 - val_accuracy: 0.8647
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4106 - accuracy: 0.8543 - val_loss: 0.3898 - val_accuracy: 0.8653
# Epoch 82/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4118 - accuracy: 0.8535 - val_loss: 0.4002 - val_accuracy: 0.8602
# Epoch 83/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4142 - accuracy: 0.8537 - val_loss: 0.3919 - val_accuracy: 0.8630
# Epoch 84/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4092 - accuracy: 0.8554 - val_loss: 0.3940 - val_accuracy: 0.8615
# Epoch 85/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4119 - accuracy: 0.8540 - val_loss: 0.3902 - val_accuracy: 0.8653
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4106 - accuracy: 0.8558 - val_loss: 0.3964 - val_accuracy: 0.8623
# Epoch 87/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4085 - accuracy: 0.8547 - val_loss: 0.3924 - val_accuracy: 0.8633
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4110 - accuracy: 0.8543 - val_loss: 0.3897 - val_accuracy: 0.8653
# Epoch 89/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4096 - accuracy: 0.8556 - val_loss: 0.3870 - val_accuracy: 0.8646
# Epoch 90/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4091 - accuracy: 0.8542 - val_loss: 0.3871 - val_accuracy: 0.8666
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4114 - accuracy: 0.8532 - val_loss: 0.3889 - val_accuracy: 0.8660
# Epoch 92/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4088 - accuracy: 0.8549 - val_loss: 0.3886 - val_accuracy: 0.8650
# Epoch 93/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4092 - accuracy: 0.8565 - val_loss: 0.3878 - val_accuracy: 0.8661
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4102 - accuracy: 0.8548 - val_loss: 0.3857 - val_accuracy: 0.8656
# Epoch 95/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4089 - accuracy: 0.8547 - val_loss: 0.3870 - val_accuracy: 0.8651
# Epoch 96/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4092 - accuracy: 0.8543 - val_loss: 0.3883 - val_accuracy: 0.8646
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4094 - accuracy: 0.8551 - val_loss: 0.3861 - val_accuracy: 0.8644
# Epoch 98/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4056 - accuracy: 0.8555 - val_loss: 0.3854 - val_accuracy: 0.8662
# Epoch 99/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4113 - accuracy: 0.8534 - val_loss: 0.3864 - val_accuracy: 0.8632
# Epoch 100/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4073 - accuracy: 0.8549 - val_loss: 0.3866 - val_accuracy: 0.8640
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3866 - accuracy: 0.8640
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3596 - accuracy: 0.8762
#     loss     (train, test): 0.3596,  0.3866
#     accuracy (train, test): 0.8762,  0.8640
# Train accuracy: 0.8761833310127258
# Test accuracy: 0.8640000224113464
